# %% [markdown]
# <a href="https://colab.research.google.com/github/jesua187/ReconocimientoPatronum/blob/main/InvCorta_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Crear un ambiente de trabajo (.ipynb) basado en PYTHON3, puede ser local (usando MINICONDA) o Cloud (i.e
# Google, IBM Cloud, etc). Crear una notebook llamada InvCorta-1.ipynb, dicha notebook debe contener
# las librerias: numpy, matplotlib, scikit-learn, pandas, jupyter notebook (esta ultima en caso de
# que sea ambiente local) como minimo, puede agregar otras libs que considere necesario. La notebook debe
# tener como minimo: Texto de varios tamanos, figuras de funciones generadas por codigo, imagenes externas,
# codigos simples que desplieguen algun valor y ecuaciones (tipo LATEX). El entregable consiste en el url de
# la notebook InvCorta-1.ipynb en GITHUB. Enviar por email (fmeza@itcr.ac.cr)

# %% [markdown]
# Dale a tu cuerpo

# %% [markdown]
# ### Alegria Macarena

# %% [markdown]
# ## EEEh Macarena!

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))

plt.stem(x, y)
plt.show() 

import numpy as np
from scipy.interpolate import splprep, splev

import matplotlib.pyplot as plt
from matplotlib.path import Path
from matplotlib.patches import PathPatch

N = 400
t = np.linspace(0, 2 * np.pi, N)
r = 0.5 + np.cos(t)
x, y = r * np.cos(t), r * np.sin(t)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   import sys

# %%
from IPython import display
display.Image("https://i.kym-cdn.com/photos/images/newsfeed/000/415/209/3b4.png")

# %%
from IPython import display
display.Image("https://littlevillagemag.com/wp-content/uploads/2020/04/computer-meme-2.jpg")

# %%
a = 8
b = 2*a
print("El doble de a es", b) 
c = 3*a
print("El triple de a es", c)
d = a/2
print("La mitad de a es", d)
# Out:
# El doble de a es 16
# El triple de a es 24
# La mitad de a es 4.0

# %% [markdown]
# Ley de Gauss
# $$
# \vec{\nabla}\cdot \vec{E}= \dfrac{\rho}
# {\epsilon_0} $$
#
# Ley de Faraday
# $$\vec{\nabla}\times\vec{E}=-\dfrac{\partial
# \vec{B}}{\partial t}$$
